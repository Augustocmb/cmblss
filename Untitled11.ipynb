# %% [markdown]
# # Polarization's anisotropies of the CMB

# %% [markdown]
# ## In this code I compute the Cls of the polarization map

# %%
# Import libraries
import matplotlib.pyplot as plt
import numpy as np
import healpy as hp 
import pymaster as nmt
# Out:
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).
#
#
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).
#
#
# WARNING: version mismatch between CFITSIO header (v4.000999999999999) and linked library (v4.01).

# %%
# read map
pol_map=hp.read_map('/home/akozameh/COM_CMB_IQU-smica_2048_R3.00_hm2.fits', [1,2])

# %%
hp.mollview(pol_map, title='Q Polarization map')

# %%
# Resolution 
map_pol=hp.pixelfunc.ud_grade(pol_map, 256)

# %%
# Read mask and apodize it on a scale of ~1deg
mask= nmt.mask_apodization(hp.read_map('/home/akozameh/cmblss/data/COM_Mask_CMB-common-Mask-Pol_2048_R3.00.fits', verbose=False),
                            1., apotype="Smooth")
# Out:
# WARNING: AstropyDeprecationWarning: "verbose" was deprecated in version 1.15.0 and will be removed in a future version.  [warnings]

# %%
#Nside =256 resolution of the map
mask=hp.pixelfunc.ud_grade(mask,256)

# %%
hp.mollview(mask, title='Apodized mask')
plt.show()

# %%
# Read healpix maps and initialize a spin-1 field
f_2 = nmt.NmtField(mask, map_pol)

# %%
# Initialize binning scheme with 4 ells per bandpower
b = nmt.NmtBin.from_nside_linear(256, 4)

# %%
# Compute MASTER estimator
# spin-2 x spin-2
cl_22 = nmt.compute_full_master(f_2, f_2, b)

# %%
# Plot results
l = b.get_effective_ells()
plt.plot(ell_arr, cl_22[0]*[(1e6)**(2)]*l*(l+1)/2/np.pi, 'b-', label='EE')
plt.plot(ell_arr, cl_22[3]*[(1e6)**(2)]*l*(l+1)/2/np.pi, 'y-', label='BB')
#plt.loglog()
plt.xlabel('$\\ell$', fontsize=16)
plt.ylabel('$C_\\ell$', fontsize=16)
plt.legend(loc='upper right', ncol=2, labelspacing=0.1)
plt.show()
